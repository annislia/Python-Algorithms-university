# %%
n=int(input())
k=int(input())
for i in range(n):
    print(k)
# Out:
#  2
#  3
# 3
# 3

# %%
a=int(input())
b=int(input())
for i in range(a,b+1):
    print(i)
# Out:
#  2
#  5
# 2
# 3
# 4
# 5

# %%
a=int(input())
b=int(input())
k=0
for i in range(b-1,a,-1):
    k+=1
    print(i)
print(k)
# Out:
#  1
#  10
# 9
# 8
# 7
# 6
# 5
# 4
# 3
# 2
# 8

# %%
c=20.4
for i in range(1,11):
    print('количество',i,' ','цена',i*c)
# Out:
# количество 1   цена 20.4
# количество 2   цена 40.8
# количество 3   цена 61.199999999999996
# количество 4   цена 81.6
# количество 5   цена 102.0
# количество 6   цена 122.39999999999999
# количество 7   цена 142.79999999999998
# количество 8   цена 163.2
# количество 9   цена 183.6
# количество 10   цена 204.0

# %%
a=int(input())
b=int(input())
h=int(input())
for i in range(a,b+1,h):
    print(i**2)
# Out:
#  2
#  4
#  1
# 4
# 9
# 16

# %%
a=int(input())
b=int(input())
h=int(input())
for i in range(a,b+1,h):
    if i>0:
        print(i)
# Out:
#  1
#  4
#  2
# 1
# 3

# %%
a=int(input())
b=int(input())
s=0
for i in range(a,b+1):
    s+=i
print(s)
# Out:
#  1
#  3
# 6

# %%
a=int(input())
b=int(input())
p=1
for i in range(a,b+1):
    p*=i
print(p)
# Out:
#  1
#  3
# 6

# %%
a=int(input())
b=int(input())
s=0
for i in range(a,b+1):
    s+=i**2
print(s)
# Out:
#  1
#  3
# 14

# %%
x=float(input())
c=1.2
while c<=2:
    print(round(c,1), round(c*x,1))
    c+=0.2
# Out:
#  1.3
# 1.2 1.6
# 1.4 1.8
# 1.6 2.1
# 1.8 2.3
# 2.0 2.6

# %%
n=int(input())
n2=0
for i in range(1, (2*n),2):
    n2+=i
print(n2)
# Out:
#  3
# 9

# %%
a= float(input())
n=int(input())
for i in range(1,n+1):
    print(a**i)
# Out:
#  1.2
#  3
# 1.2
# 1.44
# 1.7279999999999998

# %%
n=int(input())
m=[]
for k in range(1,n):
    if k**2<=n:
        m.append(k)
print(max(m))
# Out:
#  10
# 3

# %%
n=int(input())
m=[]
for k in range(1,n):
    if 3**k<n:
        m.append(k)
print(max(m))
# Out:
#  10
# 2

# %%
n=int(input())
a=float(input())
b=float(input())
h=round((b-a)/n,1)
print(h)
while a<=b:
    print(round(a,1))
    a+=h
# Out:
#  3
#  1.2
#  1.8
# 0.2
# 1.2
# 1.4
# 1.6
# 1.8

# %%
n=int(input())
s=0
for i in range(1,n+1):
    s+=1/2**i
print(s)
# Out:
#  2
# 0.75

# %%
import math
n=int(input())
x=float(input())
s=0
for i in range(1,n+1):
    s+=(math.cos(x))**i/i
print(s)
# Out:
#  3
#  1
# 0.7388417984816854

# %%
n=int(input())
s=0
for i in range(0,n+1):
    s+=(-1)**i*3**i
print(s)
# Out:
#  2
# 7

# %%
import math
n=int(input())
s=0
for i in range(1,n+1):
    s+=1/math.sin(i)
print(s)
# Out:
#  2
# 2.2881452760727377

# %%
n=int(input())
s=0
for i in range(0,n+1):
    s+=(-1)**(i+1)*i**3
print(s)
# Out:
#  3
# 20

# %%
import math
n=int(input())
s=0
for i in range(1,n+1):
    s+=(math.cos(i))*(-1)**(i+1)
print(s)
# Out:
#  2
# 0.9564491424152821

# %%
n=int(input())
x=float(input())
s=0
for i in range(1,n+1):
    s+=((-1)**(i-1)*x**i)/i
print(s)
# Out:
#  2
#  0.5
# 0.375

# %%
# import math
# n=int(input())
# s=0
# for i in range(1,n+1):
#     s+=(-1)**(i+1)*math.factorial(i)
# print(s)

n=int(input())
s=0
for i in range(1,n+1):
    f=1
    for j in range(1,i+1):
        f*=j
    s+=(-1)**(i+1)*f
print(s)
# Out:
#  1
# 1

# %%
import math
n=int(input())
x=float(input())
s=0
for i in range(1,n+1):
    s+=math.sin(x**i)
print(s)
# Out:
#  1
#  1
# 0.8414709848078965

# %%
import math
n=int(input())
s=0
for i in range(1,n+1):
    s+=1/math.factorial(i)
print(s)
# Out:
#  2
# 1.5

# %%
n=int(input())
s=0
for i in range(0,n+1):
    s+=(n+i)**2
print(s)
# Out:
#  2
# 29

# %%
import math
n=int(input())
s=0
for i in range(1,n+1):
    s+=math.factorial(i)
print(s)
# Out:
#  2
# 3

# %%
import math
n=int(input())
x=float(input())
s=0
for i in range(0,n+1):
    s+=(x**i)/math.factorial(i)
print(s)
# Out:
#  2
#  2
# 5.0

# %%
n=int(input())
x=float(input())
s=0
for i in range(0,n+1):
    s+=(-1)**i*x**i
print(s)
# Out:
#  2
#  2
# 3.0

# %%
n=int(input())
x=float(input())
s=0
for i in range(0,n+1):
    s+=(-1)**i*((x**(2*i+1))/(2*i+1))
    
print(s)
# Out:
#  2
#  3
# 42.6
