# %%
def y(a,x):
    if x>0:
        return a*x**2+1
    else:
        return a*x-1
print(y(1,3))
# Out:
# 10

# %%
def y(a,x):
    if x>=1:
        return a*x+1
    else:
        return x**2-1
print(y(1,3))
# Out:
# 4

# %%
def y(a,x):
    if x<0:
        return 3*a**2
    else:
        return 4*a*x-1
print(y(1,3))
# Out:
# 11

# %%
def y(a,x):
    if x>4:
        return 2*a**2
    else:
        return 3*x-1
print(y(1,3))
# Out:
# 8

# %%
def y(a,x):
    if x>2:
        return 2*a*x-2
    else:
        return 3*a**2-2*x
print(y(1,3))
# Out:
# 4

# %%
def y(a,x):
    if x>1:
        return 2*a*x**2-1
    else:
        return x
print(y(1,3))
# Out:
# 17

# %%
def y(a,x):
    if x>2:
        return x**2
    else:
        return 2*a-1
print(y(1,3))
# Out:
# 9

# %%
import math
def y(a,x):
    if x>2:
        return math.cos(2*x-1)
    else:
        return math.sin(3*x+1)
print(y(1,3))
# Out:
# 0.28366218546322625

# %%
def y(a,x):
    if x>2:
        return 2*x**3-2*x-1
    else:
        return 3*x**2-2*x+1
print(y(1,3))
# Out:
# 47

# %%
def y(a,x):
    if x>1:
        return 2*a*x**2-1
    else:
        return 1/a
print(y(1,3))
# Out:
# 17

# %%
def y(a,x):
    if x>=0:
        return a*x**0.5+1
    else:
        return a*x-1
print(y(1,3))
# Out:
# 2.732050807568877

# %%
def y(a,x):
    if x>0:
        return 1/x+a
    else:
        return x**2-1
print(y(1,3))
# Out:
# 1.3333333333333333

# %%
import math
def y(a,x):
    if x>math.pi/2:
        return math.cos(2*x-1)
    else:
        return math.sin(3*x+1)
print(y(1,3))
# Out:
# 4

# %%
def y(a,x):
    if x>2:
        return 2*a*x-2
    else:
        return 3*a**2-2*x
print(y(1,3))
