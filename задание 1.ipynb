# %%
import math
def y(x):
    return 3*x**2+math.sin(x)
print(y(1))
# Out:
# 3.8414709848078967

# %%
import math
def y(a, x):
    return a*x**2+math.cos(2*x+1)
print(y(1,1))
# Out:
# 0.010007503399554585

# %%
import math
def y(a,b,x):
    return a*x+b*math.sin(2*x+2)
print(y(1,1,1))
# Out:
# 0.2431975046920718

# %%
import math
def y(a, x):
    return a*x**3+math.cos(3*x+1)
print(y(1,1))
# Out:
# 0.34635637913638806

# %%
def y(a,b, x):
    return a*(x**2+4)**0.5-b
print(y(1,1,1))
# Out:
# 1.2360679774997898

# %%
import math
def y(a, x):
    return x/a+2*x**2
print(y(1,1))
# Out:
# 3.0

# %%
def y(x):
    return 3*x**2-2*x+1
print(y(1))
# Out:
# 2

# %%
def y(x):
    return 1/2*x**2-3*x+1
print(y(1))
# Out:
# -1.5

# %%
def y(a,x):
    return 1/(x**2+1)-a
print(y(1,1))
# Out:
# -0.5

# %%
import math
def y(a, x):
    return a/(x**2+1)- math.cos(2*x-1)
print(y(1,1))
# Out:
# -0.040302305868139765

# %%
def y(x):
    return x**3-2*x**2+4
print(y(1))
# Out:
# 3

# %%
def y(a,b, x):
    return a*x**2+b*x**3-8
print(y(1,1,1))
# Out:
# -6

# %%
def y(a,b, x):
    return a*(x**2+4)**0.5-b
print(y(1,1,1))
# Out:
# 1.2360679774997898

# %%
import math
def y(x):
    return math.cos(2*x-1)+math.sin(x)
print(y(1))
# Out:
# 1.3817732906760363

# %%
def y(a,b, x):
    return a*x**0.5+b*x**2
print(y(1,1,1))
# Out:
# 2.0
