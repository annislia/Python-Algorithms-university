# %%
a, b, c = int(input()),int(input()),int(input())
print('v=', a*b*c)
print('s=', 2*(a*b+b*c+a*c))
# Out:
#  1
#  2
#  2
# v= 4
# s= 16

# %%
import math
r= int(input())
print('l=', 2*math.pi*r)
print('l=', math.pi*r**2)
# Out:
#  1
# l= 6.283185307179586
# l= 3.141592653589793

# %%
a, b= int(input()),int(input())
c=(a**2+b**2)**0.5
print('c=', (a**2+b**2)**0.5)
print('p=', a+b+c)
# Out:
#  2
#  2
# c= 2.8284271247461903
# p= 6.82842712474619

# %%
import math
a, b= int(input()),int(input())
print('s1=', math.pi*a**2 )
print('s2=', math.pi*b**2)
print('s3=', math.pi*a**2-math.pi*b**2 )
# Out:
#  2
#  2
# s1= 12.566370614359172
# s2= 12.566370614359172
# s3= 0.0

# %%
import math
a, b, c, d= int(input()),int(input()),int(input()),int(input())
print('p=', 2*abs(a-c)+2*abs(b-d) )
print('s=', abs(a-c)*abs(b-d))
# Out:
#  2
#  2
#  2
#  2
# p= 0
# s= 0

# %%
import math
x1, y1, x2, y2= int(input()),int(input()),int(input()),int(input())
print('расстояние=', ((x2-x1)**2+(y2-y1)**2)**0.5)
# Out:
#  2
#  2
#  2
#  2
# расстояние= 0.0

# %%
import math
x1, y1, x2, y2, x3, y3= int(input()),int(input()),int(input()),int(input()),int(input()),int(input())
a=((x2-x1)**2+(y2-y1)**2)**0.5
b=((x3-x1)**2+(y3-y1)**2)**0.5
c=((x3-x2)**2+(y3-y2)**2)**0.5
P=a+b+c
p=P/2
print(P)
print('s=', (p*(p-a)*(p-b)*(p-c))**0.5)
# Out:
#  2
#  2
#  2
#  2
#  2
#  2
# 0.0
# s= 0.0

# %%
t= int(input())
print((t-32)*5/9)
# Out:
#  2
# -16.666666666666668

# %%
x, a, y, b = int(input()),int(input()),int(input()),int(input())
print(' 1 кг шоколадных стоит', a/x,'1 кг ирисок стоит', b/y, 'шоколадные дороже в', (a/x)/(b/y))
# Out:
#  2
#  2
#  2
#  2
#  1 кг шоколадных стоит 1.0 1 кг ирисок стоит 1.0 шоколадные дороже в 1.0

# %%
a1, b1, c1, a2, b2, c2= int(input()),int(input()),int(input()),int(input()),int(input()),int(input())
d=a1*b2-a2*b1
x=(c1*b2-c2*b1)/d
y=(a1*c2-a2*c1)/d
print(x, y)
# Out:
#  2
#  2
#  2
#  2
#  2
#  2
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[23], line 3
#       1 a1, b1, c1, a2, b2, c2= int(input()),int(input()),int(input()),int(input()),int(input()),int(input())
#       2 d=a1*b2-a2*b1
# ----> 3 x=(c1*b2-c2*b1)/d
#       4 y=(a1*c2-a2*c1)/d
#       5 print(x, y)
#
# ZeroDivisionError: division by zero

# %%
import math
a=int(input())
r=a/180*math.pi
print(r)
# Out:
#  1
# 0.017453292519943295

# %%
v1, v2, s, t= int(input()),int(input()),int(input()),int(input())
o=t*(v1+v2)
print(s+o)
# Out:
#  11
#  1
#  1
#  1
# 13

# %%
def d(x1,y1,x2,y2,x3,y3):
    ab= ((x2-x1)**2+(y2-y1)**2)**0.5
    bc= ((x3-x2)**2+(y3-y2)**2)**0.5
    return ab, bc, ab+bc
print(d(2,3,5,7,8,10))
# Out:
# (5.0, 4.242640687119285, 9.242640687119284)

# %%
a,b=int(input()), int(input())
print(a**2+b**2, a**2-b**2, a**2*b**2, a**2/b**2)
# Out:
#  3
#  2
# 13 5 36 2.25

# %%
v, u, t1, t2= int(input()), int(input()),int(input()), int(input())
s= (v+u)*t1+(v-u)*t2
print(s)
# Out:
#  10
#  2
#  1
#  1
# 20
